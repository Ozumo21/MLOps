# %% [markdown]
# ### CSV Course Specifications
#
# This is a demonstration of the course specifications linear regression algorithm using a CSV for input. This allows students to use larger data sets.
#
# This can also be viewed as a Python script in [5.export_import.py](5.export_import.py.) and [5.test_import.py](5.test_import.py).

# %% [markdown]
# #### Step 1
#
# Load the required dependencies including [pickle](https://docs.python.org/3/library/pickle.html) the native Python library for serialising data objects:
#
# > [!Caution]
# > The pickle module is not secure. Only unpickle data you trust.

# %%
# Import frameworks
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('../../style_Matplotlib_charts.mplstyle')
from sklearn.linear_model import LinearRegression
import pickle

# %% [markdown]
# ####  Step 2
# - Open and parse the CSV file and store the data as variable array objects.

# %%
# training_data = pd.read_csv('course_specifications_data.csv', delimiter=',')
training_data = pd.read_csv(r'C:\Users\Alex Zhao\Desktop\School\Software Engineering\6-Alex-Zhao\MLOps\2.Model_Development\2.3.Model_Training\2.3.2.training_data.csv', delimiter=',')
x = np.array(training_data.iloc[:,1]).reshape(-1, 1)
y = np.array(training_data.iloc[:,0])

# %% [markdown]
# #### Optional Step
#
# Apply your Python skills and query the data set about how many training examples there are and inspect a sample of the data.

# %%
m = len(x)
print(f"Number of training examples is: {m}")
table = pd.DataFrame({
    training_data.columns[0]: x.flatten(),  # Flatten x for easy display
    training_data.columns[1]: y
})
print(table.head())
# Out:
# Number of training examples is: 175
#           DoB         DoT
# 0  2024-04-02  1967-03-12
# 1  2024-12-16  1973-09-26
# 2  2024-05-20  1976-04-11
# 3  2024-06-14  1974-04-17
# 4  2024-04-13  1993-03-15

# %% [markdown]
# #### Optional Step
#
# Plot the feature `x` and target `y` data on a graph using the column headings as the graph labels.

# %%
# Plot the data points
plt.scatter(x, y, marker='x', c='r')
# Set the title
plt.title("NESA Course Specifications Data")
# Set the y-axis label
plt.ylabel(f'Training {training_data.columns[0]}')
# Set the x-axis label
plt.xlabel(f'Training {training_data.columns[1]}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Plot the data points
# ----> 2 plt.scatter(x, y, marker='x', c='r')
#       3 # Set the title
#       4 plt.title("NESA Course Specifications Data")
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)
#    3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:4927, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4925 edgecolors = kwargs.pop('edgecolor', None)
#    4926 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4927 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4928 # np.ma.ravel yields an ndarray, not a masked array,
#    4929 # unless its argument is a masked array.
#    4930 x = np.ma.ravel(x)
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_base.py:2653, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2651     # Update from data if axis is already set but no unit is set yet.
#    2652     if axis is not None and data is not None and not axis.have_units():
# -> 2653         axis.update_units(data)
#    2654 for axis_name, axis in axis_map.items():
#    2655     # Return if no axis is set.
#    2656     if axis is None:
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axis.py:1754, in Axis.update_units(self, data)
#    1752 neednew = self._converter != converter
#    1753 self._set_converter(converter)
# -> 1754 default = self._converter.default_units(data, self)
#    1755 if default is not None and self.units is None:
#    1756     self.set_units(default)
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:106, in StrCategoryConverter.default_units(data, axis)
#     104 # the conversion call stack is default_units -> axis_info -> convert
#     105 if axis.units is None:
# --> 106     axis.set_units(UnitData(data))
#     107 else:
#     108     axis.units.update(data)
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:182, in UnitData.__init__(self, data)
#     180 self._counter = itertools.count()
#     181 if data is not None:
# --> 182     self.update(data)
#
# File c:\Users\Alex Zhao\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\category.py:215, in UnitData.update(self, data)
#     213 # check if convertible to number:
#     214 convertible = True
# --> 215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
#     217     _api.check_isinstance((str, bytes), value=val)
#     218     if convertible:
#     219         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'numpy.ndarray'

# %% [markdown]
# #### Step 3
#
# Use the [sklearn](https://scikit-learn.org/stable/) library to fit the model to the training data which will provide a line of best fit with the lowest cost based on a [sklearn](https://scikit-learn.org/stable/) algorithm.

# %%
# Create the model
my_model = LinearRegression()
# Fit the model to the data
my_model.fit(x, y)

# %% [markdown]
# #### Step 4
#
# Save the model to file.

# %%
# save the model to disk
filename = 'my_saved_model.sav'
pickle.dump(my_model, open(filename, 'wb'))

# %% [markdown]
# #### Step 5
# In a separate Python implementation import the file and make a prediction.

# %%
loaded_model = pickle.load(open('my_saved_model.sav', 'rb'))
predict = np.array([4]).reshape(1, -1)
result = loaded_model.predict(predict)
print(result[0])

# %% [markdown]
# #### Optional Step
#
# Plot the features, targets and model (linear regression).

# %%
y_pred = my_model.predict(x)
plt.plot(x, y_pred)
plt.scatter(x, y, marker='x', c='r')
plt.title("NESA Course Specifications Data")
plt.ylabel(f'Training {training_data.columns[0]}')
plt.xlabel(f'Training {training_data.columns[1]}')
plt.show()

# %% [markdown]
# #### Optional Step
#
# Use the model for predictions and plot them on the visualisation that is saved as file `graph.png` for use in a Python Flask UI API endpoint.

# %%
predict = np.array([4]).reshape(1, -1)
y_prediction = my_model.predict(predict)

y_pred = my_model.predict(x)
plt.plot(x, y_pred)
plt.scatter(x, y, marker='x', c='r')
plt.scatter(predict, y_prediction, marker='D', c='r', zorder=10, s=100)
plt.text(y_prediction, predict, f"Target {y_prediction[0]} is prediction from {predict[0,0]} input")
plt.title("NESA Course Specifications Data")
plt.ylabel(f'Training {training_data.columns[0]}')
plt.xlabel(f'Training {training_data.columns[1]}')
plt.savefig('graph.png')   # save the figure to file
plt.close()    # close the figure window
